# %% [markdown]
# # Bike Share Toronto Data Processing

# %% [markdown]
# ## Chris Kimber

# %% [markdown]
# The data used comes from the City of Toronto's Open Data Portal (https://open.toronto.ca/). For this series of reports, we are using the data from 2017-2022. I have not provided the dataset on github to avoid any issues involving re-publishing the data, even if it is freely available on the portal. The pipeline below uses the data in the format available for download on the portal in April 2023; the archives were simply uncompressed before use.

# %% [markdown]
# Load necessary packages.

# %%
library(tidyverse)
library(lubridate)

# %%
setwd("../Data/ridership/")
# Out:
# Error in setwd("../Data/ridership/"): cannot change working directory
# Traceback:
#
# 1. setwd("../Data/ridership/")

# %% [markdown]
# ## Import and Cleaning 1: 2019-2022 Data

# %% [markdown]
# From an initial inspection of the data, I determined that the format of the data provided by the City of Toronto changes in several aspects over the period from 2017-2022 despite coming from the same data provider according to the city. One major change is in the columns provided in each CSV file. Not all columns are provided each year, column encoding changes, etc. The columns currently provided (as of 2022) have been used for the last 4 years, something I determined from inspecting the data manually. The folders containing CSVs that are produced by unpacking the ZIP archives provided on the Open Data Portal also have a consistent nomenclature over these 4 years (though the CSVs within do not). I will begin by importing these 4 years' worth of data together, and then import the preceding years independently to address their differences in format and make a unified dataset. To import the CSVs for these 4 years, I first find all folders using the relevant naming structure:

# %%
current_format_years <- list.files(path = ".", pattern = "^bikeshare-ridership-[2][0][0-9][0-9]")

# %% [markdown]
# Next I find all the csvs of data within these folders, and then read them all in and concatenate them in a single step. From previous inspection of the data I know there are 3 different ways in which missing data is handled in the feature encoding, so I use a custom vector to parse these as NA in readr.
#
# NOTE there is 1 CSV file (Nov 2022) that is within an enclosing ZIP file, unlike all the other CSV in these years. As the format of the CSV naming structure changes year-on-year, it is very difficult to find this automatically and it was uncovered due to manual inspection and unpacked.

# %%
current_format_csvs <- list.files(current_format_years, pattern = "*.csv", full.names = TRUE)

# %%
current_format_data <- current_format_csvs %>% map(~ read_csv(.x, name_repair = 'universal', na = c("NA", "NULL", ""))) %>% reduce(rbind)
# Out:
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 189063 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 651685 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 1130353 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 468416 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (6): Trip..Duration, Start.Time, Start.Station.Name, End.Time, End.Stati...
# dbl (4): Trip.Id, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 102148 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 95183 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 105046 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 71779 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 196224 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 370471 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 458884 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 494468 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 440662 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details, e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 277839 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (8): Start.Station.Id, Start.Time, Start.Station.Name, End.Station.Id, E...
# dbl (2): Trip.Id, Trip..Duration
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 203256 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 95348 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 86371 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 58879 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 157397 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 224299 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 424023 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 452647 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 463910 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 496943 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 454788 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 367148 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 242928 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 145849 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 56765 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 67010 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 151938 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 245920 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 504926 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 605645 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 680308 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 705150 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 602817 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 499751 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 320229 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `Trip Id` -> `Trip.Id`
# • `Trip Duration` -> `Trip..Duration`
# • `Start Station Id` -> `Start.Station.Id`
# • `Start Time` -> `Start.Time`
# • `Start Station Name` -> `Start.Station.Name`
# • `End Station Id` -> `End.Station.Id`
# • `End Time` -> `End.Time`
# • `End Station Name` -> `End.Station.Name`
# • `Bike Id` -> `Bike.Id`
# • `User Type` -> `User.Type`
# Rows: 180010 Columns: 10
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Start.Time, Start.Station.Name, End.Time, End.Station.Name, User.Type
# dbl (5): Trip.Id, Trip..Duration, Start.Station.Id, End.Station.Id, Bike.Id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(current_format_data)
# Out:
#   Trip.Id Trip..Duration Start.Station.Id Start.Time
# 1 4581278 1547           7021             01/01/2019 00:08
# 2 4581279 1112           7160             01/01/2019 00:10
# 3 4581280 589            7055             01/01/2019 00:15
# 4 4581281 259            7012             01/01/2019 00:16
# 5 4581282 281            7041             01/01/2019 00:19
# 6 4581283 624            7041             01/01/2019 00:26
#   Start.Station.Name                      End.Station.Id End.Time
# 1 Bay St / Albert St                      7233           01/01/2019 00:33
# 2 King St W / Tecumseth St                7051           01/01/2019 00:29
# 3 Jarvis St / Carlton St                  7013           01/01/2019 00:25
# 4 Elizabeth St / Edward St (Bus Terminal) 7235           01/01/2019 00:20
# 5 Edward St / Yonge St                    7257           01/01/2019 00:24
# 6 Edward St / Yonge St                    7031           01/01/2019 00:36
#   End.Station.Name                        Bike.Id User.Type
# 1 King / Cowan Ave - SMART                1296    Annual Member
# 2 Wellesley St E / Yonge St (Green P)     2947    Annual Member
# 3 Scott St / The Esplanade                2293    Annual Member
# 4 Bay St / College St (West Side) - SMART 283     Annual Member
# 5 Dundas St W / St. Patrick St            1799    Annual Member
# 6 Jarvis St / Isabella St                 661     Annual Member

# %%
tail(current_format_data)
# Out:
#   Trip.Id  Trip..Duration Start.Station.Id Start.Time
# 1 20148774 1961           7706             12/31/2022 23:56
# 2 20148775 2825           7374             12/31/2022 23:58
# 3 20148776 1764           7029             12/31/2022 23:58
# 4 20148777 469            7713             12/31/2022 23:58
# 5 20148782 588            7130             12/31/2022 23:59
# 6 20148783 795            7027             12/31/2022 23:59
#   Start.Station.Name              End.Station.Id End.Time
# 1 NA                              7677           01/01/2023 00:29
# 2 Frederick St / The Esplanade    7048           01/01/2023 00:45
# 3 Bay St / Bloor St W (East Side) 7164           01/01/2023 00:27
# 4 NA                              7028           01/01/2023 00:06
# 5 Davenport Rd / Bedford Rd       7012           01/01/2023 00:09
# 6 Beverley  St / Dundas St W      7269           01/01/2023 00:13
#   End.Station.Name                            Bike.Id User.Type
# 1 1303 Yonge St - SMART                       3076    Annual Member
# 2 Front St W / Yonge St (Hockey Hall of Fame) 788     Casual Member
# 3 Gould St / Yonge St (Ryerson University)    536     Casual Member
# 4 Gould St / Mutual St                        6306    Casual Member
# 5 Elizabeth St / Edward St (Bus Terminal)     3182    Casual Member
# 6 Toronto Eaton Centre (Yonge St)             113     Casual Member

# %%
colSums(is.na(current_format_data))
# Out:
#            Trip.Id     Trip..Duration   Start.Station.Id         Start.Time
#                  0                 16                  0                  0
# Start.Station.Name     End.Station.Id           End.Time   End.Station.Name
#             187939               5003                  0             193363
#            Bike.Id          User.Type
#                276                249

# %% [markdown]
# Inspecting the distribution of NA values, I find some concerning patterns. The high levels of missing data for station names are not themselves concerning as long as station ID is present because the stations remain identifiable. The missing duration and end station data may represent some type of failed trip or trip loggging and will be investigated further, as will the missing bike ID and user type features which have a less obvious a priori explanation.

# 3970 University Ave / Queen St W             NA             12/31/2022 20:46
# 3971 Church St  / Wood St                    NA             12/31/2022 23:32
#      End.Station.Name Bike.Id User.Type
# 1    NA               1232    Casual Member
# 2    NA               4268    Annual Member
# 3    NA               3210    Annual Member
# 4    NA               4139    Annual Member
# 5    NA               4910    Annual Member
# 6    NA               1551    Casual Member
# 7    NA               2874    Annual Member
# 8    NA               1803    Casual Member
# 9    NA               4880    Annual Member
# 10   NA               3290    Annual Member
# 11   NA               2985    Annual Member
# 12   NA               3795    Annual Member
# 13   NA               4374    Annual Member
# 14   NA               4126    Annual Member
# 15   NA               2849    Casual Member
# 16   NA               2309    Annual Member
# 17   NA               4951    Annual Member
# 18   NA               281     Casual Member
# 19   NA               2719    Casual Member
# 20   NA               2993    Annual Member
# 21   NA               688     Annual Member
# 22   NA               2360    Annual Member
# 23   NA               4842    Casual Member
# 24   NA               2319    Annual Member
# 25   NA               461     Casual Member
# 26   NA               1508    Annual Member
# 27   NA               4048    Annual Member
# 28   NA               4980    Annual Member
# 29   NA               2791    Casual Member
# 30   NA               3085    Annual Member
# ⋮    ⋮                ⋮       ⋮
# 3942 NA               6869    Annual Member
# 3943 NA               2212    Casual Member
# 3944 NA               4204    Casual Member
# 3945 NA               949     Casual Member
# 3946 NA               2072    Annual Member
# 3947 NA               6716    Casual Member
# 3948 NA               7223    Casual Member
# 3949 NA               3828    Casual Member
# 3950 NA               6245    Casual Member
# 3951 NA               7209    Annual Member
# 3952 NA               5380    Annual Member
# 3953 NA               7260    Casual Member
# 3954 NA               2027    Annual Member
# 3955 NA               5414    Casual Member
# 3956 NA               5495    Annual Member
# 3957 NA               7199    Casual Member
# 3958 NA               4785    Casual Member
# 3959 NA               3921    Casual Member
# 3960 NA               3091    Annual Member
# 3961 NA               1328    Annual Member
# 3962 NA               38      Casual Member
# 3963 NA               1466    Casual Member
# 3964 NA               6862    Casual Member
# 3965 NA               3183    Casual Member
# 3966 NA               1439    Casual Member
# 3967 NA               153     Casual Member
# 3968 NA               2302    Casual Member
# 3969 NA               1337    Casual Member
# 3970 NA               936     Casual Member
# 3971 NA               5982    Casual Member

# %% [markdown]
# The missing data for User Type is actually the most interesting, because it also illuminates errors in other factors that cause downstream problems if not detected. Inspection of the rides which are missing the user type information reveals that they all occur in October 2020 but still are just a subset of rides in that period. It appears that in all cases the data on user type appears as the Bike ID instead. Further inspection suggests that all the data has been frameshifted left by one column in these entries, and the root cause is a failure to parse between the Trip ID and Trip Duration features when the City of Toronto generated the CSV. This frameshift obviously generates nonsense data and causes immediate problems in the next step of data ingestion (correcting datatypes).

# %%
current_format_data %>% filter(is.na(current_format_data$User.Type))
# Out:
#     Trip.Id      Trip..Duration Start.Station.Id
# 1    10000084625 7120           10/03/2020 13:28
# 2    10000306555 7120           10/03/2020 13:38
# 3    10000519608 7576           10/03/2020 13:48
# 4    10000755851 7357           10/03/2020 13:58
# 5    10001076784 7313           10/03/2020 14:12
# 6   100013731087 7317           10/03/2020 14:26
# 7    10001777553 7318           10/03/2020 14:44
# 8   100020441499 7427           10/03/2020 14:55
# 3   5250             Annual Member NA
# 4   5250             Annual Member NA
# 5   5250             Annual Member NA
# 6   5250             Annual Member NA
# 7   5250             Annual Member NA
# 8   5250             Annual Member NA
# 9   5250             Annual Member NA
# 10  5250             Annual Member NA
# 11  5250             Annual Member NA
# 12  5250             Annual Member NA
# 13  5250             Annual Member NA
# 14  5250             Annual Member NA
# 15  5250             Annual Member NA
# 16  5250             Annual Member NA
# 17  5250             Annual Member NA
# 18  5250             Annual Member NA
# 19  2868             Annual Member NA
# 20  6790             Annual Member NA
# 21  6790             Annual Member NA
# 22  6790             Annual Member NA
# 23  6790             Annual Member NA
# 24  6790             Annual Member NA
# 25  6790             Annual Member NA
# 26  6790             Annual Member NA
# 27  6790             Annual Member NA
# 28  6790             Annual Member NA
# 29  6790             Annual Member NA
# 30  4679             Annual Member NA
# ⋮   ⋮                ⋮             ⋮
# 220 6604             Annual Member NA
# 221 6604             Annual Member NA
# 222 6604             Annual Member NA
# 223 6604             Annual Member NA
# 224 6604             Annual Member NA
# 225 2011             Annual Member NA
# 226 4408             Annual Member NA
# 227 5917             Annual Member NA
# 228 5917             Annual Member NA
# 229 5917             Annual Member NA
# 230 5917             Annual Member NA
# 231 5917             Annual Member NA
# 232 5917             Annual Member NA
# 233 5917             Annual Member NA
# 234 5917             Annual Member NA
# 235 5917             Annual Member NA
# 236 3828             Annual Member NA
# 237 5456             Annual Member NA
# 238 5456             Annual Member NA
# 239 5456             Annual Member NA
# 240 6584             Annual Member NA
# 241 6870             Annual Member NA
# 242 763              Annual Member NA
# 243 2614             Annual Member NA
# 244 6519             Annual Member NA
# 245 4888             Annual Member NA
# 246 5835             Annual Member NA
# 247 3814             Annual Member NA
# 248 3771             Annual Member NA
# 249 3771             Annual Member NA

# %% [markdown]
# As the Trip ID feature is sequentially numbered, it should be possible to re-parse these rows and restore their useablilty. For now, given the relatively small amount of data, I exclude it for simplicity's sake.

# %%
current_format_data <- current_format_data %>% filter(!is.na(current_format_data$User.Type))

# %% [markdown]
# I can now set the datatypes for the features related to time to simplify downstream analysis.

# %%
current_format_data <- current_format_data %>% rename(Trip.Duration = Trip..Duration) %>% mutate(across(Trip.Duration, as.numeric))

# %%
current_format_data <- current_format_data %>% mutate(across(c(Start.Time, End.Time), ~mdy_hm(.x, tz = "America/Toronto")))

# %%
head(current_format_data)
# Out:
#   Trip.Id Trip..Duration Start.Station.Id Start.Time
# 1 4581278 1547           7021             2019-01-01 00:08:00
# 2 4581279 1112           7160             2019-01-01 00:10:00
# 3 4581280 589            7055             2019-01-01 00:15:00
# 4 4581281 259            7012             2019-01-01 00:16:00
# 5 4581282 281            7041             2019-01-01 00:19:00
# 6 4581283 624            7041             2019-01-01 00:26:00
#   Start.Station.Name                      End.Station.Id End.Time
# 1 Bay St / Albert St                      7233           2019-01-01 00:33:00
# 2 King St W / Tecumseth St                7051           2019-01-01 00:29:00
# 3 Jarvis St / Carlton St                  7013           2019-01-01 00:25:00
# 4 Elizabeth St / Edward St (Bus Terminal) 7235           2019-01-01 00:20:00
# 5 Edward St / Yonge St                    7257           2019-01-01 00:24:00
# 6 Edward St / Yonge St                    7031           2019-01-01 00:36:00
#   End.Station.Name                        Bike.Id User.Type
# 1 King / Cowan Ave - SMART                1296    Annual Member
# 2 Wellesley St E / Yonge St (Green P)     2947    Annual Member
# 3 Scott St / The Esplanade                2293    Annual Member
# 4 Bay St / College St (West Side) - SMART 283     Annual Member
# 5 Dundas St W / St. Patrick St            1799    Annual Member
# 6 Jarvis St / Isabella St                 661     Annual Member

# %% [markdown]
# ## Import and Cleaning 2: 2018 Data

# %%
csvs_2018 <- list.files(path = "./bikeshare2018", pattern = "*.csv", full.names = TRUE)

# %%
data_format_2018 <- csvs_2018 %>% map(~read_csv(.x, name_repair = "universal", na = c("NA", "NULL", ""))) %>% reduce(rbind)
head(data_format_2018)
# Out:
# Rows: 178559 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, from_station_name, trip_stop_time, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 558370 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, from_station_name, trip_stop_time, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 822536 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, from_station_name, trip_stop_time, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 363490 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, from_station_name, trip_stop_time, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   trip_id trip_duration_seconds from_station_id trip_start_time
# 1 2383648  393                  7018            1/1/2018 0:47
# 2 2383649  625                  7184            1/1/2018 0:52
# 3 2383650  233                  7235            1/1/2018 0:55
# 4 2383651 1138                  7202            1/1/2018 0:57
# 5 2383652  703                  7004            1/1/2018 1:00
# 6 2383653 1026                  7078            1/1/2018 1:07
#   from_station_name                       trip_stop_time to_station_id
# 1 Bremner Blvd / Rees St                  1/1/2018 0:54  7176
# 2 Ossington Ave / College St              1/1/2018 1:03  7191
# 3 Bay St / College St (West Side) - SMART 1/1/2018 0:59  7021
# 4 Queen St W / York St (City Hall)        1/1/2018 1:16  7020
# 5 University Ave / Elm St                 1/1/2018 1:12  7060
# 6 College St / Major St                   1/1/2018 1:24  7130
#   to_station_name              user_type
# 1 Bathurst St / Fort York Blvd Annual Member
# 2 Central Tech  (Harbord St)   Annual Member
# 3 Bay St / Albert St           Annual Member
# 4 Phoebe St / Spadina Ave      Annual Member
# 5 Princess St / Adelaide St E  Annual Member
# 6 Pears Av / Avenue Rd         Annual Member

# %% [markdown]
# From a quick inspection, the biggest difference from the current format is the lack of Bike ID information, which makes it impossible to produce bike-level insights before 2019. Otherwise features just need to be renamed and reordered and datatypes homogenized.

# %%
new <- colnames(current_format_data)[-9]
old <- colnames(data_format_2018)
old_reindex <- c(1,2,3,4,5,7,6,8,9)
old <- old[order(old_reindex)]

# %%
data_2018_reformat <- data_format_2018 %>% rename_with(~new, all_of(old)) %>% 
    relocate(End.Station.Id, .before = End.Time)
head(data_2018_reformat)
# Out:
#   Trip.Id Trip.Duration Start.Station.Id Start.Time
# 1 2383648  393          7018             1/1/2018 0:47
# 2 2383649  625          7184             1/1/2018 0:52
# 3 2383650  233          7235             1/1/2018 0:55
# 4 2383651 1138          7202             1/1/2018 0:57
# 5 2383652  703          7004             1/1/2018 1:00
# 6 2383653 1026          7078             1/1/2018 1:07
#   Start.Station.Name                      End.Station.Id End.Time
# 1 Bremner Blvd / Rees St                  7176           1/1/2018 0:54
# 2 Ossington Ave / College St              7191           1/1/2018 1:03
# 3 Bay St / College St (West Side) - SMART 7021           1/1/2018 0:59
# 4 Queen St W / York St (City Hall)        7020           1/1/2018 1:16
# 5 University Ave / Elm St                 7060           1/1/2018 1:12
# 6 College St / Major St                   7130           1/1/2018 1:24
#   End.Station.Name             User.Type
# 1 Bathurst St / Fort York Blvd Annual Member
# 2 Central Tech  (Harbord St)   Annual Member
# 3 Bay St / Albert St           Annual Member
# 4 Phoebe St / Spadina Ave      Annual Member
# 5 Princess St / Adelaide St E  Annual Member
# 6 Pears Av / Avenue Rd         Annual Member

# %% [markdown]
# After renaming, a check for missing data before correcting datatypes. No NAs, what a rare treat.

# %%
colSums(is.na(data_2018_reformat))
# Out:
#            Trip.Id      Trip.Duration   Start.Station.Id         Start.Time
#                  0                  0                  0                  0
# Start.Station.Name     End.Station.Id           End.Time   End.Station.Name
#                  0                  0                  0                  0
#          User.Type
#                  0

# %% [markdown]
# Changing datatypes to match the current data format from 2019 onwards.

# %%
data_2018_reformat <- data_2018_reformat %>% mutate(across(c(Start.Station.Id, End.Station.Id), as.character))

# %%
data_2018_reformat <- data_2018_reformat %>% mutate(across(c(Start.Time, End.Time), ~mdy_hm(.x, tz = "America/Toronto")))

# %%
head(data_2018_reformat)
# Out:
#   Trip.Id Trip..Duration Start.Station.Id Start.Time
# 1 2383648  393           7018             2018-01-01 00:47:00
# 2 2383649  625           7184             2018-01-01 00:52:00
# 3 2383650  233           7235             2018-01-01 00:55:00
# 4 2383651 1138           7202             2018-01-01 00:57:00
# 5 2383652  703           7004             2018-01-01 01:00:00
# 6 2383653 1026           7078             2018-01-01 01:07:00
#   Start.Station.Name                      End.Station.Id End.Time
# 1 Bremner Blvd / Rees St                  7176           2018-01-01 00:54:00
# 2 Ossington Ave / College St              7191           2018-01-01 01:03:00
# 3 Bay St / College St (West Side) - SMART 7021           2018-01-01 00:59:00
# 4 Queen St W / York St (City Hall)        7020           2018-01-01 01:16:00
# 5 University Ave / Elm St                 7060           2018-01-01 01:12:00
# 6 College St / Major St                   7130           2018-01-01 01:24:00
#   End.Station.Name             User.Type
# 1 Bathurst St / Fort York Blvd Annual Member
# 2 Central Tech  (Harbord St)   Annual Member
# 3 Bay St / Albert St           Annual Member
# 4 Phoebe St / Spadina Ave      Annual Member
# 5 Princess St / Adelaide St E  Annual Member
# 6 Pears Av / Avenue Rd         Annual Member

# %% [markdown]
# For analysis across multiple years, I add a blank Bike ID feature to allow a proper union of tables

# %%
data_2018_compatible <- data_2018_reformat %>% add_column(Bike.Id = NA, .before = "User.Type")

# %% [markdown]
# ## Import and Cleaning 3: 2017 Data

# %%
csvs_2017 <- list.files(path = "./2017 Data", pattern = "*.csv", full.names = TRUE)

# %%
data_format_2017 <- csvs_2017 %>% map(~read_csv(.x, name_repair = "universal", na = c("NA", "NULL", ""))) %>% reduce(rbind)
# Out:
# Rows: 132123 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 333353 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 663488 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (2): trip_id, trip_duration_seconds
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 363405 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (2): trip_id, trip_duration_seconds
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Error in rbind(deparse.level, ...): numbers of columns of arguments do not match
# Traceback:
#
# 1. csvs_2017 %>% map(~read_csv(.x, name_repair = "universal", na = c("NA",
#  .     "NULL", ""))) %>% reduce(rbind)
# 2. reduce(., rbind)
# 3. reduce_impl(.x, .f, ..., .init = .init, .dir = .dir)
# 4. fn(out, elt, ...)
# 5. rbind(deparse.level, ...)
# 6. stop("numbers of columns of arguments do not match")

# %% [markdown]
# The big difference between 2017 and subsequent years is the quarterly CSVs do not all have the same format, so rbind throws an error. Loading them seperately reveals that Q3 and Q4 are missing the Station ID values to go with Station Name for both ends of a ride.

# %%
data_format_2017 <- csvs_2017 %>% map(~read_csv(.x, name_repair = "universal", na = c("NA", "NULL", "")))
# Out:
# Rows: 132123 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 333353 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (4): trip_id, trip_duration_seconds, from_station_id, to_station_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 663488 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (2): trip_id, trip_duration_seconds
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 363405 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): trip_start_time, trip_stop_time, from_station_name, to_station_name...
# dbl (2): trip_id, trip_duration_seconds
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(data_format_2017[[1]])
# Out:
#   trip_id trip_start_time trip_stop_time trip_duration_seconds from_station_id
# 1 712382  1/1/2017 0:00   1/1/2017 0:03   223                  7051
# 2 712383  1/1/2017 0:00   1/1/2017 0:05   279                  7143
# 3 712384  1/1/2017 0:05   1/1/2017 0:29  1394                  7113
# 4 712385  1/1/2017 0:07   1/1/2017 0:21   826                  7077
# 5 712386  1/1/2017 0:08   1/1/2017 0:12   279                  7079
# 6 712387  1/1/2017 0:12   1/1/2017 0:22   571                  7021
#   from_station_name                 to_station_id to_station_name
# 1 Wellesley St E / Yonge St Green P 7089          Church St  / Wood St
# 2 Kendal Ave / Bernard Ave          7154          Bathurst Subway Station
# 3 Parliament St / Aberdeen Ave      7199          College St W / Markham St
# 4 College Park South                7010          King St W / Spadina Ave
# 5 McGill St / Church St             7047          University Ave / Gerrard St W
# 6 Bay St / Albert St                7046          Niagara St / Richmond St W
#   user_type
# 1 Member
# 2 Member
# 3 Member
# 4 Member
# 5 Member
# 6 Member

# %%
head(data_format_2017[[2]])
# Out:
#   trip_id trip_start_time trip_stop_time trip_duration_seconds from_station_id
# 1 868665  1/4/2017 0:01   1/4/2017 0:06   297                  7073
# 2 868666  1/4/2017 0:07   1/4/2017 0:11   236                  7038
# 3 868667  1/4/2017 0:08   1/4/2017 0:14   380                  7012
# 4 868668  1/4/2017 0:12   1/4/2017 0:34  1299                  7172
# 5 868669  1/4/2017 0:13   1/4/2017 0:18   323                  7039
# 6 868671  1/4/2017 0:18   1/4/2017 0:24   356                  7155
#   from_station_name                       to_station_id
# 1 Bremner Blvd / Spadina Ave              7211
# 2 Dundas St / Yonge St                    7163
# 3 Elizabeth St / Edward St (Bus Terminal) 7069
# 4 Strachan Ave / Princes' Blvd            7069
# 5 Simcoe St / Dundas St W                 7021
# 6 Bathurst St / Lennox St                 7199
#   to_station_name              user_type
# 1 Fort York Blvd / Garrison Rd Member
# 2 Yonge St / Wood St           Member
# 3 Queen St W / Spadina Ave     Member
# 4 Queen St W / Spadina Ave     Member
# 5 Bay St / Albert St           Member
# 6 College St W / Markham St    Member

# %%
head(data_format_2017[[3]])
# Out:
#   trip_id trip_start_time trip_stop_time trip_duration_seconds
# 1 1253914 7/1/2017 0:00   7/1/2017 0:15   910
# 2 1253915 7/1/2017 0:01   7/1/2017 0:15   837
# 3 1253916 7/1/2017 0:01   7/1/2017 0:14   786
# 4 1253917 7/1/2017 0:01   7/1/2017 0:25  1420
# 5 1253918 7/1/2017 0:01   7/1/2017 0:25  1437
# 6 1253919 7/1/2017 0:03   7/1/2017 0:25  1332
#   from_station_name                       to_station_name            user_type
# 1 Princess St / Adelaide St E             424 Wellington St W        Member
# 2 Fort York  Blvd / Capreol Crt           HTO Park (Queens Quay W)   Casual
# 3 Fort York  Blvd / Capreol Crt           HTO Park (Queens Quay W)   Casual
# 4 Elizabeth St / Edward St (Bus Terminal) Boston Ave / Queen St E    Casual
# 5 Elizabeth St / Edward St (Bus Terminal) Boston Ave / Queen St E    Casual
# 6 Bay St / St. Joseph St                  Niagara St / Richmond St W Member

# %%
head(data_format_2017[[4]])
# Out:
#   trip_id trip_start_time   trip_stop_time    trip_duration_seconds
# 1 1971685 10/01/17 00:00:01 10/01/17 00:14:10  849
# 2 1971686 10/01/17 00:00:01 10/01/17 00:00:27   26
# 3 1971687 10/01/17 00:00:22 10/01/17 00:22:12 1310
# 4 1971688 10/01/17 00:00:38 10/01/17 00:11:09  631
# 5 1971689 10/01/17 00:00:55 10/01/17 00:20:53 1198
# 6 1971690 10/01/17 00:01:04 10/01/17 00:07:40  396
#   from_station_name
# 1 Queen St W / James St
# 2 Stewart St / Bathurst St  - SMART
# 3 Hayter St / Laplante Ave
# 4 Beverly St / College St
# 5 Thompson St / Broadview Ave - SMART
# 6 Dundonald St / Church St
#   to_station_name                             user_type
# 1 Taddle Creek Park                           Member
# 2 Stewart St / Bathurst St  - SMART           Casual
# 3 Queen St W / Portland St                    Member
# 4 Beverly  St / Dundas St W                   Member
# 5 Thompson St / Broadview Ave - SMART         Member
# 6 Victoria St / Gould St (Ryerson University) Member

# %% [markdown]
# As an interim measure, adding blank columns to the Q3 and Q4 tables will facilitate a union of the full 2017 data. In the future, using a master table of Station Name/ID may permit identifying station ID for most/all stations.

# %%
data_format_2017[[3]] <- data_format_2017[[3]] %>% add_column(from_station_id = NA, .before = "from_station_name") %>%
add_column(to_station_id = NA, .before = "to_station_name")

# %%
data_format_2017[[4]] <- data_format_2017[[4]] %>% add_column(from_station_id = NA, .before = "from_station_name") %>%
add_column(to_station_id = NA, .before = "to_station_name")

# %%
data_format_2017 <- data_format_2017 %>% reduce(rbind)

# %% [markdown]
# The features are then renamed and reordered to match the current format from 2019 onwards.

# %%
new <- colnames(current_format_data)[-9]
old2 <- colnames(data_format_2017)
old2_reindex <- c(1,4,7,2,3,5,6,8,9)
old2 <- old2[order(old2_reindex)]

# %%
data_2017_reformat <- data_format_2017 %>% rename_with(~new, all_of(old2)) %>% select(c(1,4,5,2,6,7,3,8,9))

# %%
head(data_2017_reformat)
# Out:
#   Trip.Id Trip.Duration Start.Station.Id Start.Time
# 1 712382   223          7051             1/1/2017 0:00
# 2 712383   279          7143             1/1/2017 0:00
# 3 712384  1394          7113             1/1/2017 0:05
# 4 712385   826          7077             1/1/2017 0:07
# 5 712386   279          7079             1/1/2017 0:08
# 6 712387   571          7021             1/1/2017 0:12
#   Start.Station.Name                End.Station.Id End.Time
# 1 Wellesley St E / Yonge St Green P 7089           1/1/2017 0:03
# 2 Kendal Ave / Bernard Ave          7154           1/1/2017 0:05
# 3 Parliament St / Aberdeen Ave      7199           1/1/2017 0:29
# 4 College Park South                7010           1/1/2017 0:21
# 5 McGill St / Church St             7047           1/1/2017 0:12
# 6 Bay St / Albert St                7046           1/1/2017 0:22
#   End.Station.Name              User.Type
# 1 Church St  / Wood St          Member
# 2 Bathurst Subway Station       Member
# 3 College St W / Markham St     Member
# 4 King St W / Spadina Ave       Member
# 5 University Ave / Gerrard St W Member
# 6 Niagara St / Richmond St W    Member

# %% [markdown]
# Checking for missing data shows that other than the missing station IDs from Q3/Q4, I find the expected missing data I added for Station IDs and 1 missing station name.

# %%
colSums(is.na(data_2017_reformat))
# Out:
#            Trip.Id      Trip.Duration   Start.Station.Id         Start.Time
#                  0                  0            1026893                  0
# Start.Station.Name     End.Station.Id           End.Time   End.Station.Name
#                  0            1026893                  0                  1
#          User.Type
#                  0

# %% [markdown]
# The row with a missing station name appears to be some sort of data collection failure on a ride, as the end station information is not logged and the duration is 0 minutes. There is also an unusual encoding for End Time (NULLNULL). This encoding of NA does not appear anywhere else in the dataset so I replace this sole instance with NA.

# %%
data_2017_reformat %>% filter(is.na(End.Station.Name))
# Out:
#   Trip.Id Trip.Duration Start.Station.Id Start.Time
# 1 2302635 0             NA               11/29/17 05:53:54
#   Start.Station.Name      End.Station.Id End.Time End.Station.Name User.Type
# 1 Seaton St / Dundas St E NA             NULLNULL NA               Casual

# %%
data_2017_reformat %>% filter(if_any(.fns = ~.x == "NULLNULL"))
# Out:
# Warning message:
# “Using `if_any()` without supplying `.cols` was deprecated in dplyr 1.1.0.
# ℹ Please supply `.cols` instead.”
#   Trip.Id Trip.Duration Start.Station.Id Start.Time
# 1 2302635 0             NA               11/29/17 05:53:54
#   Start.Station.Name      End.Station.Id End.Time End.Station.Name User.Type
# 1 Seaton St / Dundas St E NA             NULLNULL NA               Casual

# %%
data_2017_reformat <- data_2017_reformat %>% mutate(End.Time = replace(End.Time, End.Time == "NULLNULL", NA))

# %% [markdown]
# I then convert the station IDs to character datatype and time features to a datetime datatype. This is somewhat complicated by the fact that across the 4 quarters of 2017 there are 3 different date formats used, but lubridate is able to handle this by providing a range of formats for the parser to consider.

# %%
data_2017_reformat <- data_2017_reformat %>% mutate(across(c(Start.Station.Id, End.Station.Id), as.character)) %>%
    mutate(across(c(Start.Time, End.Time), ~parse_date_time(.x, c("dmy_HM", "mdy_HM", "mdy_HMS"), tz = "America/Toronto")))

# %% [markdown]
# Finally I recode the User Type field to match the coding used from 2018 onwards.

# %%
data_2017_reformat <- data_2017_reformat %>% mutate(User.Type = recode(User.Type, 
                                                     "Member" = "Annual Member",
                                                     "Casual" = "Casual Member"))

# %% [markdown]
# For analysis across multiple years, I add a blank Bike ID column to allow a proper union of tables

# %%
data_2017_compatible <- data_2017_reformat %>% add_column(Bike.Id = NA, .before = "User.Type")

# %% [markdown]
# ## Import and Cleaning 4: 2017-2022 Data

# %%
data_all_years <- bind_rows(current_format_data, data_2018_compatible, data_2017_compatible)

# %%
head(data_all_years)
# Out:
#   Trip.Id Trip.Duration Start.Station.Id Start.Time
# 1 4581278 1547          7021             2019-01-01 00:08:00
# 2 4581279 1112          7160             2019-01-01 00:10:00
# 3 4581280  589          7055             2019-01-01 00:15:00
# 4 4581281  259          7012             2019-01-01 00:16:00
# 5 4581282  281          7041             2019-01-01 00:19:00
# 6 4581283  624          7041             2019-01-01 00:26:00
#   Start.Station.Name                      End.Station.Id End.Time
# 1 Bay St / Albert St                      7233           2019-01-01 00:33:00
# 2 King St W / Tecumseth St                7051           2019-01-01 00:29:00
# 3 Jarvis St / Carlton St                  7013           2019-01-01 00:25:00
# 4 Elizabeth St / Edward St (Bus Terminal) 7235           2019-01-01 00:20:00
# 5 Edward St / Yonge St                    7257           2019-01-01 00:24:00
# 6 Edward St / Yonge St                    7031           2019-01-01 00:36:00
#   End.Station.Name                        Bike.Id User.Type
# 1 King / Cowan Ave - SMART                1296    Annual Member
# 2 Wellesley St E / Yonge St (Green P)     2947    Annual Member
# 3 Scott St / The Esplanade                2293    Annual Member
# 4 Bay St / College St (West Side) - SMART 283     Annual Member
# 5 Dundas St W / St. Patrick St            1799    Annual Member
# 6 Jarvis St / Isabella St                 661     Annual Member

# %% [markdown]
# There are a series of outstanding missing data problems still to fix, but at this juncture they do not inhibit use of the dataset for most analysis with sensible provisions like removal of relevant NAs in code for plotting.

# %%
colSums(is.na(data_all_years))
# Out:
#            Trip.Id      Trip.Duration   Start.Station.Id         Start.Time
#                  0                 16            1026893                  0
# Start.Station.Name     End.Station.Id           End.Time   End.Station.Name
#             187939            1031896                  1             193364
#            Bike.Id          User.Type
#            3415600                  0

# %% [markdown]
# In all rides there is information on either the ID or name of the start station, so hopefully the master list of stations can be used to fill in both features eventually. For now, the majority of analyses using the starting station should still be possible.

# %%
data_all_years %>% filter(is.na(Start.Station.Id) & is.na(Start.Station.Name))
# Out:
#      Trip.Id Trip.Duration Start.Station.Id Start.Time Start.Station.Name
#      End.Station.Id End.Time End.Station.Name Bike.Id User.Type

# %% [markdown]
# There are a non-trivial number of rides where there is no information at all about the end station but these can still be used for analyses focused on start station and duration. For the vast majority of rides, however, the missing information should be possible to reconstruct using a master list of stations

# %%
data_all_years %>% filter(is.na(End.Station.Id) & is.na(End.Station.Name))
# Out:
#      Trip.Id  Trip.Duration Start.Station.Id Start.Time
# 1    5370500    696         7228             2019-06-17 13:21:00
# 2    5679465      0         7077             2019-07-11 16:45:00
# 3    6033723    327         7444             2019-08-06 01:41:00
# 4    6735107    979         7432             2019-09-25 14:48:00
# 5    6746731     60         7077             2019-09-26 13:31:00
# 6    6750357    300         7104             2019-09-26 17:54:00
# 7    6752509   1112         7382             2019-09-26 20:13:00
